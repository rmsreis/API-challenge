# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress
from pprint import pprint #importing pprint
import requests as req

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
countries =[]

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)
        
        
# Print the city count to confirm sufficient count 
# added countries to test citypy

len(countries),len(cities)
# Out:
# (659, 659)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Using Openweather API to get the weather data needed from those cities.
# Save config information (from lesson 06/2/ activity 07 - weather stats)

# Create base URL and indicate metric units
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


#Build partial query URL
query = f"{url}appid={weather_api_key}&units={units}&q="


# preparing empty variables
city_name =[]
temp = []
hum = []
cloud = []
wind = []
lat = []
long = []


for a0 in range(len(cities)):
    response = requests.get(f"{query}{cities[a0]}").json()
# there's no data for some of the cities in openweathermap, adding exception handle for this
    try:
        city_name.append(response['name'])
        country_code.append(response['sys']['country'])                                             
        temp.append(response['main']['temp_max'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])   
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        
    except KeyError:
        city_name.append(np.nan)
        country_code.append(np.nan)
        temp.append(np.nan)
        hum.append(np.nan)
        cloud.append(np.nan)
        wind.append(np.nan)
        lat.append(np.nan)
        long.append(np.nan)
    
# set clouds and wind to zero when its not cloudy/windy
    try:
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
    except KeyError:
        cloud.append(0)
        wind.append(0)
        
    print("--------------------------------------------")
    print("Beggining Data Retrival")
    print("--------------------------------------------") 
    # Print city name and query string    
    print(f"Processing record {a0 + 1} | {cities[a0]}")
    print(f" {query} {cities[a0]}")
# Out:
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 1 | morondava
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= morondava
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 2 | bengkulu
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= bengkulu
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 3 | hermanus
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= hermanus
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 4 | jamestown
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= jamestown
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 5 | tuktoyaktuk
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= tuktoyaktuk
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 6 | ushuaia
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= ushuaia
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 7 | grindavik
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= grindavik
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 8 | nikki
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= nikki
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 9 | busselton
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= busselton
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 10 | mancio lima
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= mancio lima
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 11 | vostok
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= vostok
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 12 | taolanaro
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= taolanaro
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 13 | hervey bay
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= hervey bay
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 14 | cidreira
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= cidreira
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 15 | bredasdorp
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= bredasdorp
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 16 | vao
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= vao
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 17 | kapaa
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= kapaa
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 18 | kurush
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= kurush
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 19 | avarua
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= avarua
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 20 | inegol
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= inegol
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 21 | mocambique
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= mocambique
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 22 | westport
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= westport
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 23 | hithadhoo
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= hithadhoo
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 24 | rikitea
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= rikitea
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 25 | saint-philippe
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= saint-philippe
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 26 | coahuayana
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= coahuayana
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 27 | faya
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= faya
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 28 | burriana
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= burriana
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 29 | barentsburg
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= barentsburg
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 30 | elliot
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= elliot
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 31 | cape town
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= cape town
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 32 | umm kaddadah
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= umm kaddadah
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 33 | yulara
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= yulara
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 34 | praia da vitoria
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= praia da vitoria
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 35 | ruza
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= ruza
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 36 | miandrivazo
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= miandrivazo
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 37 | samarai
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= samarai
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 38 | lalmanir hat
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= lalmanir hat
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 39 | ust-kuyga
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= ust-kuyga
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 40 | saint george
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= saint george
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 41 | souillac
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= souillac
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 42 | khatanga
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= khatanga
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 43 | albany
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= albany
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 44 | san cristobal
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= san cristobal
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 45 | torbay
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= torbay
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 46 | half moon bay
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= half moon bay
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 47 | den helder
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= den helder
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 48 | la ronge
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= la ronge
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 49 | virginia beach
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= virginia beach
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 50 | iqaluit
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= iqaluit
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 51 | sabang
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= sabang
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record

#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= aflu
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 643 | sonepur
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= sonepur
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 644 | ciudad bolivar
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= ciudad bolivar
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 645 | marquelia
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= marquelia
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 646 | fare
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= fare
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 647 | cassilandia
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= cassilandia
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 648 | oktyabrskiy
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= oktyabrskiy
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 649 | kuusamo
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= kuusamo
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 650 | felanitx
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= felanitx
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 651 | tevaitoa
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= tevaitoa
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 652 | ampanihy
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= ampanihy
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 653 | hay river
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= hay river
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 654 | makungu
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= makungu
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 655 | gornyy
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= gornyy
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 656 | mount isa
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= mount isa
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 657 | teguise
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= teguise
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 658 | moron
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= moron
# --------------------------------------------
# Beggining Data Retrival
# --------------------------------------------
# Processing record 659 | vredendal
#  http://api.openweathermap.org/data/2.5/weather?appid=3dcc99406894c08163f13c0b407f2379&units=imperial&q= vredendal

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#limiting to 500
weather_df = pd.DataFrame({"City": city_name[0:500],
                           "Country": countries[0:500],
                           "Latitude": lat[0:500],
                           "Longitude": long[0:500],
                           "Humidity": hum[0:500],
                           "Temperature": temp[0:500],
                           "Cloudiness": cloud[0:500],
                           "Wind Speed": wind[0:500]
                          })

weather_df = weather_df.dropna(how='any')

#Save dataframe as csv
pd.DataFrame.to_csv(weather_df, 'weather_data.csv',)

weather_df.head()
# Out:
#           City Country  Latitude  Longitude  Humidity  Temperature  \
# 0    Morondava      mg    -20.30      44.28      69.0        77.51
# 3    Jamestown      sh    -33.21     138.60      92.0        52.87
# 4  Tuktoyaktuk      ca     69.44    -133.03      80.0        35.60
# 5      Ushuaia      ar    -54.81     -68.31      94.0        33.67
# 6    Grindavik      is     63.84     -22.43      87.0        48.20
#
#    Cloudiness  Wind Speed
# 0        28.0       14.72
# 3         0.0        0.00
# 4        98.0        2.71
# 5        98.0        2.71
# 6       100.0        6.67

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Plot latitude vs temperature
plt.scatter(weather_df['Latitude'], weather_df['Temperature'])
plt.title('City Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)
plt.axvline(x=0,c="g",alpha=0.5)


#save as .png
plt.savefig('lattitude_vs_temp.png', bbox_inches='tight')

# %% [markdown]
# Comment:
#
# As expected, Weather becomes warmer as we approach the equater and similar temperature at around latitude +/- 40

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Plot latitude vs humidity
plt.scatter(weather_df['Latitude'], weather_df['Humidity'])
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)
plt.axvline(x=0,c="g",alpha=0.5)


#save as png
plt.savefig('lat_humid.png', bbox_inches='tight')

# %% [markdown]
# There is not much relationship between latitude and humidity for latitude higher than 20 degree (north or south) where the humidity is slightly higher, data points are very randomly distributed

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Plot latitude vs cloudiness and save as .png
plt.scatter(weather_df['Latitude'], weather_df['Cloudiness'])
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)
plt.axvline(x=0,c="g",alpha=0.5)

# save as png
plt.savefig('lat_cloud.png', bbox_inches='tight')

# %% [markdown]
# This plot is very ramdly distributed depicting the lack relationship between latitude and cloudiness.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Plot latitude vs wind speed
plt.scatter(weather_df['Latitude'], weather_df['Wind Speed'])
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.axvline(x=0,c="g",alpha=0.5)

#save as png
plt.savefig('lat_wind.png', bbox_inches='tight')

# %% [markdown]
# Wind speed seems to be very constant and independent of the latitude
